# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('training_dataset.csv')

# %%
df.head()
# Out:
#   label  word_count  num_stop_words  num_chars  num_punctuation_chars  \
# 0   ham          20               4        111                      9
# 1   ham           6               0         29                      6
# 2  spam          28               5        155                      5
# 3   ham          11               2         49                      6
# 4   ham          13               6         61                      2
#
#    word_count_after_preprocessing  num_chars_after_preprocessing  \
# 0                              16                             82
# 1                               6                             23
# 2                              20                            110
# 3                               9                             35
# 4                               8                             40
#
#    vector_dim_1  vector_dim_2  vector_dim_3  ...  vector_dim_91  \
# 0     -0.580355      0.007112     -0.976935  ...       0.518878
# 1     -0.427296     -0.043355     -0.790381  ...       0.326726
# 2     -0.219919      0.018497     -0.652489  ...       0.153814
# 3     -0.624623      0.055353     -1.439270  ...       0.667178
# 4     -0.331633     -0.067030     -1.235357  ...       0.939712
#
#    vector_dim_92  vector_dim_93  vector_dim_94  vector_dim_95  vector_dim_96  \
# 0       0.497694      -0.090783       0.009786       0.404360      -0.024591
# 1       0.445335      -0.144925       0.105700       0.364651      -0.027538
# 2       0.264300       0.085201       0.226342       0.216582      -0.001449
# 3       0.806222      -0.131574       0.124313       0.451901      -0.234886
# 4       0.105435      -0.233439       0.112147      -0.122173       0.130926
#
#    vector_dim_97  vector_dim_98  vector_dim_99  vector_dim_100
# 0       0.145488      -0.293120       0.501582       -0.175949
# 1       0.004716      -0.113986       0.182881       -0.253901
# 2      -0.046417      -0.281185       0.236028       -0.549548
# 3      -0.067293      -0.029182       0.448625       -0.219913
# 4       0.006515      -0.164775       1.332866       -0.211998
#
# [5 rows x 107 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['label'])

# %%
x=df.drop(columns='label')

# %%
x
# Out:
#        word_count  num_stop_words  num_chars  num_punctuation_chars  \
# 0              20               4        111                      9
# 1               6               0         29                      6
# 2              28               5        155                      5
# 3              11               2         49                      6
# 4              13               6         61                      2
# ...           ...             ...        ...                    ...
# 14612         131              59        745                     24
# 14613         121              62        670                     18
# 14614         141              72        770                      9
# 14615          86              47        448                     16
# 14616         260             139       1363                     35
#
#        word_count_after_preprocessing  num_chars_after_preprocessing  \
# 0                                  16                             82
# 1                                   6                             23
# 2                                  20                            110
# 3                                   9                             35
# 4                                   8                             40
# ...                               ...                            ...
# 14612                              74                            517
# 14613                              63                            430
# 14614                              69                            490
# 14615                              41                            266
# 14616                             126                            845
#
#        vector_dim_1  vector_dim_2  vector_dim_3  vector_dim_4  ...  \
# 0         -0.580355      0.007112     -0.976935     -0.082504  ...
# 1         -0.427296     -0.043355     -0.790381      0.007617  ...
# 2         -0.219919      0.018497     -0.652489      0.086807  ...
# 3         -0.624623      0.055353     -1.439270     -0.068720  ...
# 4         -0.331633     -0.067030     -1.235357     -0.688138  ...
# ...             ...           ...           ...           ...  ...
# 14612     -0.342951     -0.075643     -1.186137     -0.375801  ...
# 14613     -0.297361     -0.135439     -1.199637     -0.433341  ...
# 14614     -0.336334     -0.135865     -1.247379     -0.403766  ...
# 14615     -0.438449     -0.073349     -1.116723     -0.389665  ...
# 14616     -0.414568     -0.125897     -1.152089     -0.421651  ...
#
#        vector_dim_91  vector_dim_92  vector_dim_93  vector_dim_94  \
# 0           0.518878       0.497694      -0.090783       0.009786
# 1           0.326726       0.445335      -0.144925       0.105700
# 2           0.153814       0.264300       0.085201       0.226342
# 3           0.667178       0.806222      -0.131574       0.124313
# 4           0.939712       0.105435      -0.233439       0.112147
# ...              ...            ...            ...            ...
# 14612       0.801224       0.111723       0.127505       0.266898
# 14613       0.920119       0.085622       0.229993       0.302630
# 14614       0.946064       0.125366       0.388100       0.307724
# 14615       0.790470       0.178357       0.226579       0.250889
# 14616       0.947870       0.199644       0.153053       0.252963
#
#        vector_dim_95  vector_dim_96  vector_dim_97  vector_dim_98  \
# 0           0.404360      -0.024591       0.145488      -0.293120
# 1           0.364651      -0.027538       0.004716      -0.113986
# 2           0.216582      -0.001449      -0.046417      -0.281185
# 3           0.451901      -0.234886      -0.067293      -0.029182
# 4          -0.122173       0.130926       0.006515      -0.164775
# ...              ...            ...            ...            ...
# 14612      -0.002344       0.037983      -0.183323      -0.352511
# 14613      -0.120674       0.033732      -0.367308      -0.270141
# 14614      -0.184426      -0.050521      -0.444589      -0.242708
# 14615      -0.079787      -0.032070      -0.175590      -0.308300
# 14616      -0.069350       0.030297      -0.262230      -0.275914
#
#        vector_dim_99  vector_dim_100
# 0           0.501582       -0.175949
# 1           0.182881       -0.253901
# 2           0.236028       -0.549548
# 3           0.448625       -0.219913
# 4           1.332866       -0.211998
# ...              ...             ...
# 14612       1.124732       -0.297396
# 14613       1.208777       -0.356910
# 14614       1.172409       -0.299430
# 14615       1.017424       -0.372482
# 14616       1.187338       -0.324914
#
# [14617 rows x 106 columns]

# %%
y=df['label']

# %%
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 14612    0
# 14613    0
# 14614    0
# 14615    0
# 14616    0
# Name: label, Length: 14617, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Initializing the Random Forest model with class_weight='balanced'
rf_model = RandomForestClassifier(n_estimators=100,class_weight='balanced', random_state=42)

# Fitting the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
# Predictions
y_pred = rf_model.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.95

# %%
# Print confusion matrix and classification report
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[2221   34]
#  [ 114  555]]

# %%
# Evaluating the model
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      2255
#            1       0.94      0.83      0.88       669
#
#     accuracy                           0.95      2924
#    macro avg       0.95      0.91      0.93      2924
# weighted avg       0.95      0.95      0.95      2924

# %%
from sklearn.metrics import roc_auc_score
y_pred_proba = rf_model.predict_proba(X_test)
roc_auc_score(y_test, y_pred_proba[:, 0])
# Out:
# np.float64(0.016031472993082968)

# %%
from sklearn.metrics import roc_auc_score
y_pred_proba = rf_model.predict_proba(X_test)
roc_auc_score(y_test, y_pred_proba[:, 1])
# Out:
# np.float64(0.983968527006917)

# %% [markdown]
# now we tune the hyperparameters

# %%
import os
import joblib
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# Custom scoring function
def custom_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    penalty = fp + 0.5 * fn  # Adjust weights if necessary
    return penalty  # We return penalty as lower is better

# Hyperparameter grid
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', None]
}

# Define the checkpoint file path
checkpoint_path = 'manual_search_checkpoint.pkl'

# Load checkpoint or initialize
if os.path.exists(checkpoint_path):
    print("Loading checkpoint from previous run...")
    checkpoint_data = joblib.load(checkpoint_path)
    start_index = checkpoint_data['start_index']
    results = checkpoint_data['results']
else:
    print("No checkpoint found, starting manual grid search from scratch...")
    start_index = 0
    results = []

# Create the parameter combinations manually
from itertools import product
param_combinations = list(product(param_grid['n_estimators'],
                                  param_grid['max_depth'],
                                  param_grid['min_samples_split'],
                                  param_grid['min_samples_leaf'],
                                  param_grid['max_features']))

# Real-time update CSV file
csv_file_path = 'manual_search_results.csv'
if not os.path.exists(csv_file_path):
    # If file doesn't exist, create it with the header
    pd.DataFrame(columns=['n_estimators', 'max_depth', 'min_samples_split', 
                          'min_samples_leaf', 'max_features', 'FP', 'FN', 'Penalty']).to_csv(csv_file_path, index=False)

# Variable to track the best model
best_penalty = float('inf')
best_params = None

# Train 32 models based on parameter combinations
try:
    for i in range(start_index, min(len(param_combinations), 32)):
        params = param_combinations[i]

        # Unpack the parameters
        n_estimators, max_depth, min_samples_split, min_samples_leaf, max_features = params

        # Initialize RandomForestClassifier with the current parameters
        rf = RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            max_features=max_features,
            class_weight='balanced',
            random_state=42
        )

        # Train the model
        rf.fit(X_train, y_train)

        # Predict on the test set
        y_pred = rf.predict(X_test)

        # Compute confusion matrix and extract FP, FN
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        # Calculate the penalty for the current model
        penalty = custom_score(y_test, y_pred)

        # Append the results to the DataFrame
        new_row = {
            'n_estimators': n_estimators,
            'max_depth': max_depth,
            'min_samples_split': min_samples_split,
            'min_samples_leaf': min_samples_leaf,
            'max_features': max_features,
            'FP': fp,
            'FN': fn,
            'Penalty': penalty
        }

        # Append results to the CSV file immediately after each evaluation
        pd.DataFrame([new_row]).to_csv(csv_file_path, index=False, mode='a', header=False)

        # Check if this is the best model so far
        if penalty < best_penalty:
            best_penalty = penalty
            best_params = params

        # Save progress to checkpoint after each model
        results.append(new_row)
        checkpoint_data = {'start_index': i + 1, 'results': results}
        joblib.dump(checkpoint_data, checkpoint_path)

        print(f"Model {i+1}/32 evaluated with penalty: {penalty}.")

except Exception as e:
    print(f"An error occurred: {e}")
    # Save the current progress to a checkpoint file before exiting
    checkpoint_data = {'start_index': i, 'results': results}
    joblib.dump(checkpoint_data, checkpoint_path)
    print("Progress saved to checkpoint.")

# After the process completes, delete the checkpoint file if desired
if len(results) == 32:
    os.remove(checkpoint_path)  # Remove checkpoint file after successful completion

# Show the results DataFrame
print(pd.read_csv(csv_file_path))

# Print the best hyperparameters
if best_params:
    print(f"Best hyperparameters: n_estimators={best_params[0]}, max_depth={best_params[1]}, "
          f"min_samples_split={best_params[2]}, min_samples_leaf={best_params[3]}, "
          f"max_features={best_params[4]} with penalty {best_penalty}")
# Out:
# No checkpoint found, starting manual grid search from scratch...
# Model 1/32 evaluated with penalty: 165.5.
# Model 2/32 evaluated with penalty: 156.5.
# Model 3/32 evaluated with penalty: 160.0.
# Model 4/32 evaluated with penalty: 160.5.
# Model 5/32 evaluated with penalty: 164.5.
# Model 6/32 evaluated with penalty: 157.0.
# Model 7/32 evaluated with penalty: 160.0.
# Model 8/32 evaluated with penalty: 157.5.
# Model 9/32 evaluated with penalty: 97.5.
# Model 10/32 evaluated with penalty: 112.5.
# Model 11/32 evaluated with penalty: 103.0.
# Model 12/32 evaluated with penalty: 112.0.
# Model 13/32 evaluated with penalty: 96.5.
# Model 14/32 evaluated with penalty: 111.5.
# Model 15/32 evaluated with penalty: 105.0.
# Model 16/32 evaluated with penalty: 113.0.
# Model 17/32 evaluated with penalty: 156.5.
# Model 18/32 evaluated with penalty: 158.0.
# Model 19/32 evaluated with penalty: 160.5.
# Model 20/32 evaluated with penalty: 159.0.
# Model 21/32 evaluated with penalty: 162.0.
# Model 22/32 evaluated with penalty: 159.0.
# Model 23/32 evaluated with penalty: 156.0.
# Model 24/32 evaluated with penalty: 160.0.
# Model 25/32 evaluated with penalty: 96.0.
# Model 26/32 evaluated with penalty: 108.5.
# Model 27/32 evaluated with penalty: 103.5.
# Model 28/32 evaluated with penalty: 107.5.
# Model 29/32 evaluated with penalty: 101.0.
# Model 30/32 evaluated with penalty: 106.5.
# Model 31/32 evaluated with penalty: 103.5.
# Model 32/32 evaluated with penalty: 107.5.
#     n_estimators  max_depth  min_samples_split  min_samples_leaf max_features  \
# 0            100         10                  2                 1         sqrt
# 1            100         10                  2                 1          NaN
# 2            100         10                  2                 2         sqrt
# 3            100         10                  2                 2          NaN
# 4            100         10                  5                 1         sqrt
# ..           ...        ...                ...               ...          ...
# 59           200         20                  2                 2          NaN
# 60           200         20                  5                 1         sqrt
# 61           200         20                  5                 1          NaN
# 62           200         20                  5                 2         sqrt
# 63           200         20                  5                 2          NaN
#
#      FP   FN  Penalty
# 0   112   69    146.5
# 1   139   74    176.0
# 2   113   70    148.0
# 3   140   75    177.5
# 4   110   68    144.0
# ..  ...  ...      ...
# 59   55  105    107.5
# 60   49  104    101.0
# 61   54  105    106.5
# 62   57   93    103.5
# 63   57  101    107.5
#
# [64 rows x 8 columns]
# Best hyperparameters: n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=sqrt with penalty 96.0

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[2198   57]
#  [ 101  568]]

# %%
# Evaluate the final model
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      2255
#            1       0.91      0.85      0.88       669
#
#     accuracy                           0.95      2924
#    macro avg       0.93      0.91      0.92      2924
# weighted avg       0.95      0.95      0.95      2924

# %% [markdown]
# ### WIth best hyperparameters

# %%
# Initializing the Random Forest model with class_weight='balanced'
rf_model = RandomForestClassifier(n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features='sqrt',class_weight='balanced', random_state=42)

# Fitting the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=20,
#                        min_samples_leaf=2, min_samples_split=5,
#                        random_state=42)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.95

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[2198   57]
#  [ 101  568]]

# %%
# Evaluate the final model
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      2255
#            1       0.91      0.85      0.88       669
#
#     accuracy                           0.95      2924
#    macro avg       0.93      0.91      0.92      2924
# weighted avg       0.95      0.95      0.95      2924

# %%
import pickle

# Save the model
with open('random_forest__beset_model.pkl', 'wb') as file:
    pickle.dump(rf_model, file)
