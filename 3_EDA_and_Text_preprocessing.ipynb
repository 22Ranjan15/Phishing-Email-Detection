# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('spam_notSpam.csv')

# %%
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (14619, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   14619 non-null  object
#  1   text    14618 non-null  object
# dtypes: object(2)
# memory usage: 228.6+ KB

# %%
df[df['text'].isna()]
# Out:
#       label text
# 12991  spam  NaN

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (14618, 2)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[(df['text'].str.strip() == '')]
# Out:
#       label text
# 12859  spam

# %%
df[(df['label'].str.strip() == '')]
# Out:
# Empty DataFrame
# Columns: [label, text]
# Index: []

# %%
df = df[~(df['text'].str.strip() == '')]

# %%
df.shape
# Out:
# (14617, 2)

# %%
df['text']=df['text'].str.lower()

# %%
df
# Out:
#       label                                               text
# 0       ham  go until jurong point, crazy.. available only ...
# 1       ham                      ok lar... joking wif u oni...
# 2      spam  free entry in 2 a wkly comp to win fa cup fina...
# 3       ham  u dun say so early hor... u c already then say...
# 4       ham  nah i don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 14614   ham  problems started when i booked the intercontin...
# 14615   ham  the amalfi hotel has a beautiful website and i...
# 14616   ham  the intercontinental chicago magnificent mile ...
# 14617   ham  the palmer house hilton, while it looks good i...
# 14618   ham  as a former chicagoan, i'm appalled at the ama...
#
# [14617 rows x 2 columns]

# %%
df[df['text'].apply(lambda x:x.endswith(' ') or x.startswith(' '))]
# Out:
#       label                                               text
# 4269    ham  cha quiteamuzing thatscool babe,probpop in & ...
# 5694   spam  subject: ? ? ? ? ? ? ? ? erp !\r\n? ????? ? ? ...
# 10150   ham   date wed number aug number number number numb...
# 10151   ham  martin a posted tassos papadopoulos the greek ...
# 10152   ham  man threatens explosion in moscow thursday aug...
# ...     ...                                                ...
# 13578  spam   we enjoyed our stay at the swissotel in downt...
# 13597  spam   the hard rock hotel chicago is great alternat...
# 13695  spam   if you are traveling anywhere near lake michi...
# 13747  spam   we just returned from a relaxing stay at the ...
# 13793  spam   if you are traveling to chicago and need a pl...
#
# [2868 rows x 2 columns]

# %%
df['text']=df['text'].str.strip()

# %%
df[df['text'].apply(lambda x:x.endswith(' ') or x.startswith(' '))]
# Out:
# Empty DataFrame
# Columns: [label, text]
# Index: []

# %%
# Identify comments containing URLs
url_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'

# %%
email_contains_url=df[df['text'].str.contains(url_pattern,regex=True)]

# %%
email_contains_url
# Out:
#       label                                               text
# 15     spam  xxxmobilemovieclub: to use your credit, click ...
# 301    spam  sms. ac blind date 4u!: rodds1 is 21/m from ab...
# 509    spam  your credits have been topped up for http://ww...
# 624    spam  dear voucher holder, 2 claim this weeks offer,...
# 812    spam  dear voucher holder, to claim this weeks offer...
# 859    spam  reminder: you have not downloaded the content ...
# 1077   spam  message important information for o2 user. tod...
# 1362   spam  urgent, important information for o2 user. tod...
# 2897   spam  you are now unsubscribed all services. get ton...
# 3001   spam  dear voucher holder, to claim this weeks offer...
# 3265   spam  bloomberg -message center +447797706009 why wa...
# 3628   spam  free msg: ringtone!from: http://tms. widelive....
# 3649   spam  a link to your picture has been sent. you can ...
# 3904   spam  dear voucher holder, to claim this weeks offer...
# 3936   spam  important information 4 orange user 0796xxxxxx...
# 3983   spam  important information 4 orange user . today is...
# 4003   spam  urgent. important information for 02 user. tod...
# 4070   spam  important information 4 orange user 0789xxxxxx...
# 4619   spam  dear voucher holder have your next meal on us....
# 13847   ham  this hotel is very busy and is operating way b...

# %%
email_contains_url.shape
# Out:
# (20, 2)

# %%
email_with_newline=df[df['text'].str.contains('\n')]

# %%
email_with_newline
# Out:
#       label                                               text
# 4727    ham  keep ur problems in ur heart, b'coz nobody wil...
# 5157    ham  subject: enron methanol ; meter # : 988291\r\n...
# 5158    ham  subject: hpl nom for january 9 , 2001\r\n( see...
# 5159    ham  subject: neon retreat\r\nho ho ho , we ' re ar...
# 5160   spam  subject: photoshop , windows , office . cheap ...
# ...     ...                                                ...
# 10145   ham  subject: fw : crosstex energy , driscoll ranch...
# 10146   ham  subject: put the 10 on the ft\r\nthe transport...
# 10147   ham  subject: 3 / 4 / 2000 and following noms\r\nhp...
# 10148   ham  subject: industrial worksheets for august 2000...
# 10149  spam  subject: important online banking alert\r\ndea...
#
# [4916 rows x 2 columns]

# %%
df['text']=df['text'].str.replace('\n',' ',regex=True)

# %%
df[df['text'].str.contains('\n')]
# Out:
# Empty DataFrame
# Columns: [label, text]
# Index: []

# %% [markdown]
# # EDA with text preprocessing

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data=df,x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
df['label'].value_counts(normalize=True).mul(100).round(2)
# Out:
# label
# ham     77.23
# spam    22.77
# Name: proportion, dtype: float64

# %%
df['word_count']=df['text'].apply(lambda x:len(x.split()))

# %%
df.sample(5)
# Out:
#      label                                               text  word_count
# 1205   ham  nobody can decide where to eat and dad wants c...          10
# 5331   ham  subject: eastrans october first of the month n...          39
# 5583   ham  subject: revision - forest oil ' s january 200...         183
# 6358  spam  subject: date / fuck / flirt\r no\r thanks of ...          20
# 4870  spam  urgent! please call 09061213237 from a landlin...          23

# %%
df['word_count'].describe()
# Out:
# count    14617.000000
# mean       148.180612
# std        339.398245
# min          1.000000
# 25%         17.000000
# 50%         61.000000
# 75%        167.000000
# max      13303.000000
# Name: word_count, dtype: float64

# %%
sns.displot(df['word_count'],kde=True)

# %%
# Create the figure and axes
plt.figure(figsize=(10, 6))

# Plot KDE for category 1
sns.kdeplot(df[df['label'] == "spam"]['word_count'], label='Spam', fill=True)

# Plot KDE for category 0
sns.kdeplot(df[df['label'] == "ham"]['word_count'], label='Ham', fill=True)



# Add title and labels
plt.title('Word Count Distribution by Category')
plt.xlabel('Word Count')
plt.ylabel('Density')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
sns.boxplot(df['word_count'])
# Out:
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='word_count'>

# %%
# Create a boxplot for the 'wordcount' column categorized by 'label'
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='label', y='word_count')
plt.title('Boxplot of Word Count by Category')
plt.xlabel('label')
plt.ylabel('Word Count')
plt.show()
# Out:
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Create a scatterplot between 'label' and 'wordcount'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='label', y='word_count', alpha=0.5)
plt.title('Scatterplot of Word Count by Category')
plt.xlabel('Label')
plt.ylabel('Word Count')
plt.show()

# %%
# median word counts among label

sns.barplot(df,x='label',y='word_count',estimator='median')
# Out:
# <Axes: xlabel='label', ylabel='word_count'>

# %% [markdown]
# # EDA with text preprocessing

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\ranja\appdata\roaming\python\python312\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\ranja\appdata\roaming\python\python312\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\ranja\appdata\roaming\python\python312\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ranja\appdata\roaming\python\python312\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\ranja\appdata\roaming\python\python312\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\ranja\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from nltk.corpus import stopwords

# Download NLTK stopwords if not already downloaded
import nltk
nltk.download('stopwords')

# Define the list of English stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ranja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Create a new column 'num_stop_words' by counting the number of stopwords in each comment
df['num_stop_words'] = df['text'].apply(lambda x: len([word for word in x.split() if word in stop_words]))

# %%
df.sample(10)
# Out:
#       label                                               text  word_count  \
# 7648    ham  subject: re : hydrocarbon lease mgmt .\r daren...         325
# 2771    ham                      thanks chikku..:-) gud nyt:-*           4
# 4783    ham  hi darlin im on helens fone im gonna b up the ...          20
# 13238  spam  i stayed here august 20 through 23rd with my s...         101
# 222     ham  would really appreciate if you call me. just n...          13
# 12043   ham  url url date wed number sep number number numb...          21
# 2490    ham  r u &sam p in eachother. if we meet we can go ...          15
# 9621    ham  subject: re : meter 5848\r vance ,\r what is t...         498
# 4726    ham  mark works tomorrow. he gets out at 5. his wor...          20
# 6589    ham  subject: tenaska iv\r darren :\r please change...          61
#
#        num_stop_words
# 7648               46
# 2771                0
# 4783                4
# 13238              47
# 222                 4
# 12043               0
# 2490                6
# 9621              105
# 4726               10
# 6589               10

# %%
df['num_stop_words'].describe()
# Out:
# count    14617.000000
# mean        47.031197
# std        124.973790
# min          0.000000
# 25%          5.000000
# 50%         16.000000
# 75%         56.000000
# max       5667.000000
# Name: num_stop_words, dtype: float64

# %%
# Create a distribution plot (displot) for the 'num_stop_words' column
plt.figure(figsize=(10, 6))
sns.histplot(df['num_stop_words'], kde=True)
plt.title('Distribution of Stop Word Count in Comments')
plt.xlabel('Number of Stop Words')
plt.ylabel('Frequency')
plt.show()

# %%
# Create the figure and axes
plt.figure(figsize=(10, 6))

# Plot KDE for category 1
sns.kdeplot(df[df['label'] == "spam"]['num_stop_words'], label='Spam', fill=True)

# Plot KDE for category 0
sns.kdeplot(df[df['label'] == "ham"]['num_stop_words'], label='Ham', fill=True)



# Add title and labels
plt.title('num_stop_words Distribution by label')
plt.xlabel('num_stop_words')
plt.ylabel('Density')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
# median word counts among emails

sns.barplot(df,x='label',y='num_stop_words',estimator='median')
# Out:
# <Axes: xlabel='label', ylabel='num_stop_words'>

# %%
# !pip install collections
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for collections

# %%
# Create a frequency distribution of stop words in the 'text' column
from collections import Counter

# Extract all stop words from the comments using the previously defined 'common_stopwords'
all_stop_words = [word for comment in df['text'] for word in comment.split() if word in stop_words]

# Count the most common stop words
most_common_stop_words = Counter(all_stop_words).most_common(25)

# Convert the most common stop words to a DataFrame for plotting
top_25_df = pd.DataFrame(most_common_stop_words, columns=['stop_word', 'count'])

# Create the barplot for the top 25 most common stop words
plt.figure(figsize=(12, 8))
sns.barplot(data=top_25_df, x='count', y='stop_word', palette='viridis')
plt.title('Top 25 Most Common Stop Words')
plt.xlabel('Count')
plt.ylabel('Stop Word')
plt.show()
# Out:
# C:\Users\ranja\AppData\Local\Temp\ipykernel_15636\2971076169.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_25_df, x='count', y='stop_word', palette='viridis')
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
df
# Out:
#       label                                               text  word_count  \
# 0       ham  go until jurong point, crazy.. available only ...          20
# 1       ham                      ok lar... joking wif u oni...           6
# 2      spam  free entry in 2 a wkly comp to win fa cup fina...          28
# 3       ham  u dun say so early hor... u c already then say...          11
# 4       ham  nah i don't think he goes to usf, he lives aro...          13
# ...     ...                                                ...         ...
# 14614   ham  problems started when i booked the intercontin...         131
# 14615   ham  the amalfi hotel has a beautiful website and i...         121
# 14616   ham  the intercontinental chicago magnificent mile ...         141
# 14617   ham  the palmer house hilton, while it looks good i...          86
# 14618   ham  as a former chicagoan, i'm appalled at the ama...         260
#
#        num_stop_words
# 0                   4
# 1                   0
# 2                   5
# 3                   2
# 4                   6
# ...               ...
# 14614              59
# 14615              62
# 14616              72
# 14617              47
# 14618             139
#
# [14617 rows x 4 columns]

# %%
df['num_chars']=df['text'].apply(len)

# %%
df.head()
# Out:
#   label                                               text  word_count  \
# 0   ham  go until jurong point, crazy.. available only ...          20
# 1   ham                      ok lar... joking wif u oni...           6
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...          28
# 3   ham  u dun say so early hor... u c already then say...          11
# 4   ham  nah i don't think he goes to usf, he lives aro...          13
#
#    num_stop_words  num_chars
# 0               4        111
# 1               0         29
# 2               5        155
# 3               2         49
# 4               6         61

# %%
df['num_chars'].describe()
# Out:
# count     14617.000000
# mean        763.350961
# std        2465.838412
# min           2.000000
# 25%          87.000000
# 50%         313.000000
# 75%         855.000000
# max      200406.000000
# Name: num_chars, dtype: float64

# %%
from collections import Counter

# Combine all comments into one large string
all_text = ' '.join(df['text'])

# Count the frequency of each character
char_frequency = Counter(all_text)

# Convert the character frequency into a DataFrame for better display
char_frequency_df = pd.DataFrame(char_frequency.items(), columns=['character', 'frequency']).sort_values(by='frequency', ascending=False)

# %%
char_frequency_df['character'].values
# Out:
# array([' ', 'e', 't', 'a', 'o', 'n', 'r', 'i', 's', 'l', 'h', 'u', 'm',
#        'c', 'd', 'b', 'p', 'f', 'y', 'g', 'w', '\r', 'v', '-', '.', 'k',
#        '0', ',', '_', '/', 'j', 'x', '1', ':', '2', '3', '5', '9', 'z',
#        '4', 'q', '@', "'", '8', '6', '7', '?', ')', '!', '(', '>', ';',
#        '=', '"', '$', '#', '&', '*', '|', '%', '+', ']', '[', 'é', '\x01',
#        '£', 'ü', '`', '\\', '~', '}', '{', 'ä', '이', 'à', '^', 'è', '的',
#        '\x92', '는', '‘', '<', '다', '에', '서', '인', '리', 'ç', '고', '있', '하',
#        '은', 'ÿ', '有', '你', '의', '보', '在', '분', '야', '一', '지', '관', '자',
#        'ö', '…', '사', '您', '件', 'ı', '어', '告', '한', '가', '地', '最', '不',
#        'ê', '도', '로', '路', '就', '人', '을', '기', '시', '行', '到', '일', '\x0f',
#        '子', '으', '면', '我', '是', 'い', '信', '해', '스', '方', '직', 'î', '무',
#        'ò', '上', '증', '부', '아', '想', '高', '址', '호', '업', 'の', '\x12', '들',
#        '격', '–', '대', 'は', '력', '요', '트', '站', 'を', '터', '中', '如', '服',
#        '를', '全', '티', '금', '융', '以', '상', '出', '송', '높', '테', 'á', '司',
#        '公', '건', '피', '정', '메', '收', 'ß', '用', '可', '網', '수', '니', 'し',
#        '핑', '提', '성', '商', '방', 'ト', '每', '天', '下', '款', '会', '之', '나',
#        '많', '業', '此', '這', '要', 'イ', '客', '여', '주', '球', 'な', 'た', '게',
#        '축', '뷰', '쇼', '되', '索', '事', '及', '등', '학', '所', '性', '라', '名',
#        '조', '後', '供', '장', '网', '效', '전', '果', '機', '能', '원', 'ま', '종',
#        '了', 'に', '또', '請', '작', '험', '搜', '좋', '多', '好', '실', '今', '만',
#        '적', '部', '권', '美', '群', '個', '送', '會', '계', 'ó', '大', '추', '們',
#        '需', '企', '재', '式', '\x94', '广', '생', '等', '소', '우', '和', '销', 'ş',
#        '然', '중', '分', '련', '통', '港', '看', '신', '意', '유', '男', '特', '幔',
#        '按', 'で', '심', 'â', '며', '务', '料', '반', '快', 'ン', '태', '直', '선',
#        'お', '거', '산', '成', '步', '년', '周', 'ô', 'る', '整', '做', '鴉', '坐',
#        'が', '隻', '请', '為', 'う', '兔', '烏', '推', 'り', 'サ', '許', '新', '户',
#        '過', '宣', '来', '为', 'リ', '回', '量', '擎', '比', '市', '免', 'さ', '道',
#        '知', '售', '自', '無', '專', '息', '時', '起', '香', '突', '通', '普', '工',
#        '必', '者', '低', '碛', '格', '电', '年', '打', '己', '力', '月', '保', '引',
#        '河', '받', '내', '星', '행', '습', '文', '외', '\x14', '남', '꽃', '불', '넷',
#        '바', '즘', '근', '본', '급', '과', '었', '髅', '구', '까', '드', '록', '음',
#        '올', '’', '투', '위', '황', '경', '\x96', '각', '광', '입', '용', '硇', '創',
#        '致', '何', '往', '主', '远', '鐘', '쪽', '순', '갖', '同', '展', '것', '럼',
#        '그', '功', '法', '握', 'ù', '速', '捷', '訓', '報', '表', '再', '현', '몰',
#        '刻', '付', '濾', '치', '定', '謝', 'ë', '掌', 'û', '场', '得', '廣', '任',
#        '代', '發', '비', '接', '준', '廉', '때', '름', '因', '家', '氖', '費', '品',
#        '\x13', 'ク', 'ス', 'プ', 'レ', 'ゼ', '\x16', '¡', '迎', '营', 'ア', 'と',
#        '发', '黼', 'け', 'チ', '\t', 'っ', 'ぐ', '女', '\x93', '进', '\x91', '試',
#        'ポ', 'よ', '“', '求', '希', '望', '晶', 'ッ', '流', 'ー', '铡', '正', '影',
#        '解', '查', '와', '세', '임', '見', '具', '作', '국', '앞', 'メ', 'ル', '¹',
#        '失', '礼', '제', '션', 'こ', '広', '패', 'ご', 'ぃ', 'そ', '旨', '뜨', '²',
#        '³', '留', '们', '隊', '源', '底', '법', '率', '團', '均', '若', '예', '著',
#        '천', '朋', '友', '번', '식', '려', '也', '꾸', '常', '而', '익', '都', '문',
#        '理', '뉴', '않', '합', '升', '日', '眨', '湍', '및', '얼', '미', '包', '樹',
#        '但', '러', '디', '說', '마', '學', '발', '資', '又', '할', '히', '득', '將',
#        '心', '明', '入', '맑', '只', '脈', '담', '限', '元', '障', '沒', '降', '避',
#        '盗', '麂', '斗', '各', '享', '馍', '英', '登', '⒘', '⒓', '次', '韧', '域',
#        '张', '位', '王', 'φ', '项', '酝', '傩', '欤', '根', '越', '舻', '枰', '指',
#        '即', '澳', '剑', '获', '磕', '联', '晟', '频', '碾', '严', '髂', '除', '删',
#        '将', '扰', '存', '歉', '抱', '感', '深', '系', '二', '淄', '惶', '幸', '衍',
#        '布', '蚀', '便', '福', '值', '产', '或', '拿', '紫', '壕', '建', '寄', '套',
#        '业', '超', '惠', '某', '橙', '四', '其', '被', '区', '省', 'χ', '个', '遍',
#        '估', '印', '国', '模', '于', 'ｉ', '恼', '技', '活', '资', '甩', '后', '面',
#        '痪', 'ｚ', '问', '第', '访', '帧', 'κ', '垮', '桑', '⑹', '蔷', '时', '危',
#        '侄', '菏', '麓', '拥', '烹', '投', '幅', '调', '它', '注', '九', '案', '放',
#        '鞣', '媒', '麽', '绞', '那', '本', '赤', '碓', '未', '耪', '横', '顷', '箱',
#        '嗟', '蕉', '待', '实', '隧', '价', '髁', '迅', '世', '平', '遇', '戮', '立',
#        '粽', '暨', '缘', '完', 'れ', '컬', '브', '영', '람', '센', '따', '쁘', '곱',
#        '즈', '뿐', '겨', '양', '렉', '너', '필', '헤', '크', '네', '롯', '츠', '포',
#        '맞', '활', '강', '께', '함', '란', '목', '망', '쯤', '죄', '啥', '當', '啦',
#        '嗎', '兒', '樣', '問', '감', '겠', '노', '릭', '클', '단', '촉', '없', '락',
#        '허', '저', '먼', '른', '된', '알', '웹', '귀', '률', '진', '봐', '표', '止',
#        '뽑', '혔', '꼽', '힘', '붐', '링', '델', '모', '타', '블', '케', '홈', '싶',
#        '젊', '떤', 'ï', '\x05', '\x07', '\x1b', '\x11', '〨', '┾', '鈥', 'ì',
#        '—', '»', 'ú', '처', '확', '간', '두', '점', '롭', '새', '운', '떨', '향',
#        '더', '극', '몇', '씬', '훨', '토', '취', '말', '특', '쓰', '채', '카', '별',
#        '차', '했', '열', '느', '파', '렵', '될', '休', '來', '狐', '賺', '住', '話',
#        '電', '姓', '頁', '首', '碟', '光', '取', '片', '線', '錢', '鬆', '諒', '輕',
#        '進', '運', '祝', '懂', '夢', '闆', '老', '小', '圓', '萬', '導', '擾', '拒',
#        '狸', '使', '停', '配', 'セ', 'ら', 'め', 'つ', '娘', '気', '前', '当', 'て',
#        '迷', 'ど', '氏', '欲', 'き', '飽', '応', '対', 'ャ', 'キ', '帯', '携', 'ラ',
#        'ハ', 'す', '輔', '裡', '造', '才', '努', '跟', '願', '決', '怕', '銷', '趣',
#        '興', '細', '仔', '呢', '夠', '候', '甘', '麼', '什', '生', '愛', '親', '須',
#        '訴', '故', '吃', '給', '把', '現', '薪', '績', '長', '屬', '秒', '門', '叩',
#        '富', '利', '啊', '呦', '勿', '由', '託', '委', '設', '驟', '照', '結', '連',
#        '教', '郵', '封', '另', '絡', '聯', '與', '儘', '加', '空'], dtype=object)

# %%
char_frequency_df.tail(50)
# Out:
#     character  frequency
# 492         趣          1
# 491         興          1
# 489         細          1
# 488         仔          1
# 482         呢          1
# 481         夠          1
# 479         候          1
# 604         甘          1
# 477         麼          1
# 476         什          1
# 475         生          1
# 472         愛          1
# 471         親          1
# 469         須          1
# 463         訴          1
# 461         故          1
# 459         吃          1
# 458         給          1
# 457         把          1
# 456         現          1
# 513         薪          1
# 519         績          1
# 521         長          1
# 524         屬          1
# 602         秒          1
# 600         門          1
# 599         叩          1
# 598         富          1
# 594         利          1
# 586         啊          1
# 584         呦          1
# 579         勿          1
# 573         由          1
# 572         託          1
# 571         委          1
# 564         設          1
# 563         驟          1
# 561         照          1
# 560         結          1
# 559         連          1
# 558         教          1
# 553         郵          1
# 552         封          1
# 543         另          1
# 541         絡          1
# 540         聯          1
# 538         與          1
# 536         儘          1
# 529         加          1
# 980         空          1

# %%
char_frequency_df['character'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 2
# 19     e
# 5      t
# 13     a
# 1      o
#       ..
# 540    聯
# 538    與
# 536    儘
# 529    加
# 980    空
# Name: character, Length: 981, dtype: object>

# %%
# Create a new column 'num_punctuation_chars' to count punctuation characters in each comment
df['num_punctuation_chars'] = df['text'].apply(
    lambda x: sum([1 for char in x if char in '.,!?;:"\'()[]{}-'])
)

df.sample(5)
# Out:
#       label                                               text  word_count  \
# 6210    ham  subject: neon week # 9\r - experiencing god we...          12
# 13082  spam  this a great property, excellent location and ...          94
# 6395    ham  subject: producer shut - in list for victoria ...         378
# 11342   ham  indeed i was thinking of getting back into doi...          81
# 13978   ham  all i can say is avoid this place at all costs...          80
#
#        num_stop_words  num_chars  num_punctuation_chars
# 6210                0         55                      3
# 13082              49        519                     16
# 6395               43       1749                     80
# 11342              19        514                      0
# 13978              34        411                     10

# %%
df['num_punctuation_chars'].describe()
# Out:
# count    14617.000000
# mean        20.366833
# std         59.363642
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         17.000000
# max       4245.000000
# Name: num_punctuation_chars, dtype: float64

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Create a function to extract the top 25 bigrams
def get_top_ngrams(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:n]

# Get the top 25 bigrams
top_25_bigrams = get_top_ngrams(df['text'], 25)

# Convert the bigrams into a DataFrame for plotting
top_25_bigrams_df = pd.DataFrame(top_25_bigrams, columns=['bigram', 'count'])

# Plot the countplot for the top 25 bigrams
plt.figure(figsize=(12, 8))
sns.barplot(data=top_25_bigrams_df, x='count', y='bigram', palette='magma')
plt.title('Top 25 Most Common Bigrams')
plt.xlabel('Count')
plt.ylabel('Bigram')
plt.show()
# Out:
# C:\Users\ranja\AppData\Local\Temp\ipykernel_15636\1622265995.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_25_bigrams_df, x='count', y='bigram', palette='magma')
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Create a function to extract the top 25 trigrams
def get_top_trigrams(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:n]

# Get the top 25 trigrams
top_25_trigrams = get_top_trigrams(df['text'], 25)

# Convert the trigrams into a DataFrame for plotting
top_25_trigrams_df = pd.DataFrame(top_25_trigrams, columns=['trigram', 'count'])

# Plot the countplot for the top 25 trigrams
plt.figure(figsize=(12, 8))
sns.barplot(data=top_25_trigrams_df, x='count', y='trigram', palette='coolwarm')
plt.title('Top 25 Most Common Trigrams')
plt.xlabel('Count')
plt.ylabel('Trigram')
plt.show()
# Out:
# C:\Users\ranja\AppData\Local\Temp\ipykernel_15636\3726095756.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_25_trigrams_df, x='count', y='trigram', palette='coolwarm')
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ranja\AppData\Roaming\Python\Python312\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Remove non-English characters from the 'clean_comment' column
# Keeping only standard English letters, digits, and common punctuation
import re

df['text'] = df['text'].apply(lambda x: re.sub(r'[^A-Za-z0-9\s!?.,]', '', str(x)))

# %%
char_frequency_df
# Out:
#     character  frequency
# 2                2166838
# 19          e    1003154
# 5           t     700297
# 13          a     632032
# 1           o     621017
# ..        ...        ...
# 540         聯          1
# 538         與          1
# 536         儘          1
# 529         加          1
# 980         空          1
#
# [981 rows x 2 columns]

# %%
all_text = ' '.join(df['text'])

# Count the frequency of each character
char_frequency = Counter(all_text)

# Convert the character frequency into a DataFrame for better display
char_frequency_df = pd.DataFrame(char_frequency.items(), columns=['character', 'frequency']).sort_values(by='frequency', ascending=False)

char_frequency_df
# Out:
#    character  frequency
# 2               2166838
# 19         e    1003154
# 5          t     700297
# 13         a     632032
# 1          o     621017
# 4          n     590493
# 9          r     557244
# 6          i     545061
# 20         s     499182
# 7          l     356095
# 24         h     330324
# 3          u     305704
# 25         m     285841
# 12         c     284919
# 22         d     283278
# 18         b     188461
# 10         p     185369
# 23         f     167642
# 15         y     160984
# 0          g     159514
# 21         w     147770
# 42        \r      93324
# 17         v      90964
# 16         .      79177
# 26         k      76582
# 29         0      61555
# 11         ,      50505
# 8          j      31297
# 31         x      30644
# 28         1      30580
# 27         2      28341
# 36         3      17377
# 30         5      15591
# 39         9      15133
# 14         z      14584
# 35         4      14250
# 34         q      13625
# 32         8      12478
# 40         6      11964
# 33         7      10707
# 38         ?       8476
# 37         !       6414
# 41        \t          2

# %%
df.head()
# Out:
#   label                                               text  word_count  \
# 0   ham  go until jurong point, crazy.. available only ...          20
# 1   ham                      ok lar... joking wif u oni...           6
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...          28
# 3   ham  u dun say so early hor... u c already then say...          11
# 4   ham  nah i dont think he goes to usf, he lives arou...          13
#
#    num_stop_words  num_chars  num_punctuation_chars
# 0               4        111                      9
# 1               0         29                      6
# 2               5        155                      5
# 3               2         49                      6
# 4               6         61                      2

# %%
top_25_df
# Out:
#    stop_word  count
# 0        the  70415
# 1         to  46634
# 2        and  35411
# 3          a  30061
# 4         of  27853
# 5          i  23276
# 6         in  21361
# 7        for  20345
# 8        you  17873
# 9         is  17730
# 10      that  14473
# 11      this  14166
# 12        on  14120
# 13        it  12850
# 14        we  10111
# 15      with  10038
# 16       was   9960
# 17        be   9919
# 18      have   9134
# 19        at   8990
# 20      from   8688
# 21       not   8298
# 22         s   8225
# 23       are   7902
# 24      your   7713

# %%
from nltk.corpus import stopwords

# Defining stop words but keeping essential ones for sentiment analysis
stop_words = set(stopwords.words('english')) - {'not', 'but', 'however', 'no', 'yet'}

# Remove stop words from 'text' column, retaining essential ones
df['text'] = df['text'].apply(
    lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words])
)

# %% [markdown]
# there are some word that will completely change the meaning of a sentence

# %%
df.head()
# Out:
#   label                                               text  word_count  \
# 0   ham  go jurong point, crazy.. available bugis n gre...          20
# 1   ham                      ok lar... joking wif u oni...           6
# 2  spam  free entry 2 wkly comp win fa cup final tkts 2...          28
# 3   ham          u dun say early hor... u c already say...          11
# 4   ham       nah dont think goes usf, lives around though          13
#
#    num_stop_words  num_chars  num_punctuation_chars
# 0               4        111                      9
# 1               0         29                      6
# 2               5        155                      5
# 3               2         49                      6
# 4               6         61                      2

# %%
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')

# Define the lemmatizer
lemmatizer = WordNetLemmatizer()

# Apply lemmatization to the 'text ' column that contains no stopwords
df['text'] = df['text'].apply(
    lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()])
)

df.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ranja\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#   label                                               text  word_count  \
# 0   ham  go jurong point, crazy.. available bugis n gre...          20
# 1   ham                      ok lar... joking wif u oni...           6
# 2  spam  free entry 2 wkly comp win fa cup final tkts 2...          28
# 3   ham          u dun say early hor... u c already say...          11
# 4   ham          nah dont think go usf, life around though          13
#
#    num_stop_words  num_chars  num_punctuation_chars
# 0               4        111                      9
# 1               0         29                      6
# 2               5        155                      5
# 3               2         49                      6
# 4               6         61                      2

# %% [markdown]
# Lemmatization is a process in natural language processing (NLP) used to reduce words to their base or root form, known as a lemma, while ensuring that the resulting word is an actual word in the language. Unlike stemming, which simply cuts off suffixes to achieve a root form, lemmatization considers the context of the word and its part of speech to return a valid base form.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def plot_word_cloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(text))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

plot_word_cloud(df['text'])

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def plot_word_cloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(text))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

plot_word_cloud(df[df['label'] == "spam"]['text'])

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def plot_word_cloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(text))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

plot_word_cloud(df[df['label'] == "ham"]['text'])

# %%
def plot_top_n_words(df, n=20):
    """Plot the top N most frequent words in the dataset."""
    # Flatten all words in the content column
    words = ' '.join(df['text']).split()

    # Get the top N most common words
    counter = Counter(words)
    most_common_words = counter.most_common(n)

    # Split the words and their counts for plotting
    words, counts = zip(*most_common_words)

    # Plot the top N words
    plt.figure(figsize=(10, 6))
    sns.barplot(x=list(counts), y=list(words))
    plt.title(f'Top {n} Most Frequent Words')
    plt.xlabel('Frequency')
    plt.ylabel('Words')
    plt.show()

# Example usage
plot_top_n_words(df, n=50)

# %%
import matplotlib.pyplot as plt

def plot_top_n_words_by_category(df, n=20, start=0):
    """Plot the top N most frequent words in the dataset with stacked hue based on category (spam/ham)."""
    
    # Flatten all words in the text column and count their occurrences by category
    word_category_counts = {}

    for idx, row in df.iterrows():
        words = row['text'].split()
        category = row['label']  # Assuming 'label' column exists with values 'spam' or 'ham'

        for word in words:
            if word not in word_category_counts:
                word_category_counts[word] = {"spam": 0, "ham": 0}  # Initialize counts for each category

            # Increment the count for the corresponding category
            word_category_counts[word][category] += 1

    # Get total counts across all categories for each word
    total_word_counts = {word: sum(counts.values()) for word, counts in word_category_counts.items()}

    # Get the top N most frequent words across all categories
    most_common_words = sorted(total_word_counts.items(), key=lambda x: x[1], reverse=True)[start:start+n]
    top_words = [word for word, _ in most_common_words]

    # Prepare data for plotting
    word_labels = top_words
    spam_counts = [word_category_counts[word]["spam"] for word in top_words]
    ham_counts = [word_category_counts[word]["ham"] for word in top_words]
    
    # Plot the stacked bar chart
    plt.figure(figsize=(12, 8))
    bar_width = 0.75

    # Plot spam counts in red
    plt.barh(word_labels, spam_counts, color='red', label='Spam', height=bar_width)

    # Plot ham counts in green, stacked on top of spam
    plt.barh(word_labels, ham_counts, left=spam_counts, color='green', label='Ham', height=bar_width)

    # Add labels and title
    plt.xlabel('Counts')
    plt.ylabel('Words')
    plt.title(f'Top {n} Word Frequencies by Category (Spam and Ham)')
    plt.legend()

    # Display the plot
    plt.tight_layout()
    plt.show()

# Assuming 'df' is a DataFrame that has a 'text' column and a 'label' column with 'spam' or 'ham'
plot_top_n_words_by_category(df, n=20)

# %%
df
# Out:
#       label                                               text  word_count  \
# 0       ham  go jurong point, crazy.. available bugis n gre...          20
# 1       ham                      ok lar... joking wif u oni...           6
# 2      spam  free entry 2 wkly comp win fa cup final tkts 2...          28
# 3       ham          u dun say early hor... u c already say...          11
# 4       ham          nah dont think go usf, life around though          13
# ...     ...                                                ...         ...
# 14614   ham  problem started booked intercontinental chicag...         131
# 14615   ham  amalfi hotel beautiful website interior decora...         121
# 14616   ham  intercontinental chicago magnificent mile outs...         141
# 14617   ham  palmer house hilton, look good pictures, outsi...          86
# 14618   ham  former chicagoan, im appalled amalfi hotel chi...         260
#
#        num_stop_words  num_chars  num_punctuation_chars
# 0                   4        111                      9
# 1                   0         29                      6
# 2                   5        155                      5
# 3                   2         49                      6
# 4                   6         61                      2
# ...               ...        ...                    ...
# 14614              59        745                     24
# 14615              62        670                     18
# 14616              72        770                      9
# 14617              47        448                     16
# 14618             139       1363                     35
#
# [14617 rows x 6 columns]

# %%
def clean_text(text):
        # Remove URLs
        text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
        
        # Remove email addresses
        text = re.sub(r'\S+@\S+', '', text)
        
        # Remove HTML tags
        text = re.sub(r'<.*?>', '', text)
        
        # Remove special characters and numbers
        text = re.sub(r'[^a-zA-Z\s]', '', text)

        return text

# %%
# Apply the clean_text function to the specified column
df['text'] = df['text'].apply(clean_text)

# %% [markdown]
# we have count the words, stop_words, chars , punctuation before text_preprocessing of the emails ,now we will count these all after preprocessing

# %%
df['word_count_after_preprocessing']=df['text'].apply(lambda x:len(x.split()))

# %%
df.head()
# Out:
#   label                                               text  word_count  \
# 0   ham  go jurong point crazy available bugis n great ...          20
# 1   ham                            ok lar joking wif u oni           6
# 2  spam  free entry  wkly comp win fa cup final tkts st...          28
# 3   ham                u dun say early hor u c already say          11
# 4   ham           nah dont think go usf life around though          13
#
#    num_stop_words  num_chars  num_punctuation_chars  \
# 0               4        111                      9
# 1               0         29                      6
# 2               5        155                      5
# 3               2         49                      6
# 4               6         61                      2
#
#    word_count_after_preprocessing
# 0                              16
# 1                               6
# 2                              20
# 3                               9
# 4                               8

# %%
df['num_chars_after_preprocessing']=df['text'].apply(len)

# %%
df.head()
# Out:
#   label                                               text  word_count  \
# 0   ham  go jurong point crazy available bugis n great ...          20
# 1   ham                            ok lar joking wif u oni           6
# 2  spam  free entry  wkly comp win fa cup final tkts st...          28
# 3   ham                u dun say early hor u c already say          11
# 4   ham           nah dont think go usf life around though          13
#
#    num_stop_words  num_chars  num_punctuation_chars  \
# 0               4        111                      9
# 1               0         29                      6
# 2               5        155                      5
# 3               2         49                      6
# 4               6         61                      2
#
#    word_count_after_preprocessing  num_chars_after_preprocessing
# 0                              16                             82
# 1                               6                             23
# 2                              20                            110
# 3                               9                             35
# 4                               8                             40

# %%
df.to_csv("cleaned_text.csv",index=False)
